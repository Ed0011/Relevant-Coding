# %%
import pandas as pd
from rdkit import Chem
from rdkit.Chem import PandasTools
import numpy as np
from molvs import standardize_smiles

# %%
TDB=pd.read_excel('Tautomer_database_release_3a.xlsx', na_values='nul',usecols=['Solvent', 'SMILES_1',  'Quantitative_ratio_1', 'SMILES_2',  'Quantitative_ratio_2'])
TDB
# Out:
#                    Solvent                                           SMILES_1  \
# 0                Gas phase                                      O=C(C)CC(C)=O
# 1                Gas phase                                       N1=CC=N[NH]1
# 2                     HMPT                                         CC1=CC=NN1
# 3                  DMSO-d6                             N=N=NC1=NNC2=CC=CC=C12
# 4     Carbon tetrachloride                CC1([C@H]2C(C=O)=C(O)[C@@](CC2)1C)C
# ...                    ...                                                ...
# 2814                   THF  ClC1=CC=C(C=C1)N=NC2=C(C=CC=C2)P(C3=CC=CC=C3)C...
# 2815                   THF  ClC2=CC(=C(N=NC1=CC=CC=C1)C=C2)P(C3=CC=CC=C3)C...
# 2816                   THF  ClC1=CC=C(C=C1)N=NC2=C(C=C(C=C2)C)P(C3=CC=CC=C...
# 2817                   THF  ClC2=CC(=C(N=NC1=CC=C(C)C=C1)C=C2)P(C3=CC=CC=C...
# 2818                   THF  ClC2=CC(=C(N=NC1=CC=C(Cl)C=C1)C=C2)P(C3=CC=CC=...
#
#      Quantitative_ratio_1                                           SMILES_2  \
# 0                     NaN                                    O/C(C)=C\C(C)=O
# 1                     NaN                                       [NH]1N=NC=C1
# 2                     NaN                                         CC1=NNC=C1
# 3                     NaN                             N=N=NC1=C2C=CC=CC2=NN1
# 4                     NaN                CC1([C@H](CC[C@@](C)1C/2=O)C2=C\O)C
# ...                   ...                                                ...
# 2814                5.848  ClC1=CC=C(C=C1)[N]2[N-]C5=C([P+]2(C3=CC=CC=C3)...
# 2815                1.715  C1=CC=C(C=C1)[N]2[N-]C5=C([P+]2(C3=CC=CC=C3)C4...
# 2816                69.93  ClC1=CC=C(C=C1)[N]2[N-]C5=C([P+]2(C3=CC=CC=C3)...
# 2817               13.947  ClC5=CC1=C([N-][N]([P+]1(C2=CC=CC=C2)C3=CC=CC=...
# 2818                <0.99  ClC1=CC=C(C=C1)[N]2[N-]C5=C([P+]2(C3=CC=CC=C3)...
#
#      Quantitative_ratio_2
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ...                   ...
# 2814               94.152
# 2815               98.285
# 2816                30.07
# 2817               86.053
# 2818               >99.01
#
# [2819 rows x 5 columns]

# %%
TDB=TDB.query("Solvent=='Water' or Solvent=='Water-d2'")
TDB=TDB.dropna(subset=['Quantitative_ratio_2'],how='any')
TDB=TDB.reset_index(drop=True)
TDB
# Out:
#      Solvent                                      SMILES_1  \
# 0      Water                              O=C1C=C(Cl)NC=C1
# 1      Water                                  O=C1NC=NC=C1
# 2      Water                              CC1=C(C)C(ON1)=O
# 3      Water                       OC1=CC(C2=CC=CC=C2)=NO1
# 4      Water                    OC1=C(C)C(C2=CC=CC=C2)=NO1
# 5      Water                   O=C1C(Br)C(C2=CC=CC=C2)=NO1
# 6      Water                                 O=C1C=C(C)NO1
# 7      Water                          O=C1CC(C(C)(C)C)=NO1
# 8      Water         O=C1CC(C2=CC=C([N+]([O-])=O)C=C2)=NO1
# 9      Water                   O=C1C=C(C2=CC=C(OC)C=C2)NO1
# 10     Water                                    OCCCC(C)=O
# 11     Water                                   OCCCCC(C)=O
# 12     Water      O=C2C3=C(C=CC=C3)/C(C=C2)=N/NC1=CC=CC=C1
# 13     Water   O=C2C3=C(C=CC=C3)/C(C=C2)=N/NC1=CC=C(C)C=C1
# 14     Water  O=C2C3=C(C=CC=C3)/C(C=C2)=N/NC1=CC=C(Cl)C=C1
# 15     Water  O=C2C3=C(C=CC=C3)/C(C=C2)=N/NC1=CC=C(OC)C=C1
# 16     Water                           ON1N=C2C=CC=CC2=C1C
# 17  Water-d2              OB(C1=C(C(F)=CC([H])=C1)C=O)O[H]
# 18  Water-d2                                    O=C1NCC=C1
# 19     Water            O=[S](CC1=CC=NC=C1)(C2=CC=CC=C2)=O
# 20     Water                O=C1C3=C(CC2=C1C=CC=C2)C=CC=C3
#
#    Quantitative_ratio_1                                    SMILES_2  \
# 0                  0.55                            OC1=CC(Cl)=NC=C1
# 1                   0.7                                O=C1N=CNC=C1
# 2                <0.010                              CC(C1C)=NOC1=O
# 3                   NaN                     O=C1ON=C(C1)C2=CC=CC=C2
# 4                <0.100                    O=C1ON=C(C1C)C2=CC=CC=C2
# 5                   0.2                 O=C1C(Br)=C(C2=CC=CC=C2)NO1
# 6                   0.3                               O=C1CC(C)=NO1
# 7                   0.7                        O=C1C=C(C(C)(C)C)NO1
# 8                   0.8       O=C1C=C(C2=CC=C([N+]([O-])=O)C=C2)NO1
# 9                   0.2                 O=C1CC(C2=CC=C(OC)C=C2)=NO1
# 10                    1                                 OC1(C)CCCO1
# 11                    1                                OC1(C)CCCCO1
# 12             0.701493      OC4=CC=C(/N=N/C6=CC=CC=C6)C5=C4C=CC=C5
# 13             0.579832   OC4=CC=C(/N=N/C6=CC=C(C)C=C6)C5=C4C=CC=C5
# 14             0.642857  OC4=CC=C(/N=N/C6=CC=C(Cl)C=C6)C5=C4C=CC=C5
# 15             0.450549  OC4=CC=C(/N=N/C6=CC=C(OC)C=C6)C5=C4C=CC=C5
# 16                 0.35            [O-][N+]3=C(C)C4=C(N3[H])C=CC=C4
# 17             0.854701             OB(C2=C3C(F)=CC([H])=C2)OC3O[H]
# 18               66.667                                  O=C1NC=CC1
# 19                99.99          O=[S](C=C1C=CNC=C1)(C2=CC=CC=C2)=O
# 20                99.32                OC2=C1C=CC=CC1=CC3=C2C=CC=C3
#
#    Quantitative_ratio_2
# 0                  0.45
# 1                   0.3
# 2                <0.200
# 3                   0.7
# 4                <0.100
# 5                   0.8
# 6                   0.7
# 7                   0.3
# 8                   0.2
# 9                   0.8
# 10                    0
# 11                    0
# 12             0.298507
# 13             0.420168
# 14             0.357143
# 15             0.549451
# 16                 0.65
# 17             0.145299
# 18               33.333
# 19                    0
# 20                 0.68

# %%
for i in range(len(TDB)):
    if type(TDB.loc[i, 'Quantitative_ratio_1'])==str or TDB.loc[i, 'Quantitative_ratio_1']==1 or pd.isnull(TDB.loc[i, 'Quantitative_ratio_1']):
        TDB=TDB.drop(i)

TDB
# Out:
#      Solvent                                      SMILES_1  \
# 0      Water                              O=C1C=C(Cl)NC=C1
# 1      Water                                  O=C1NC=NC=C1
# 5      Water                   O=C1C(Br)C(C2=CC=CC=C2)=NO1
# 6      Water                                 O=C1C=C(C)NO1
# 7      Water                          O=C1CC(C(C)(C)C)=NO1
# 8      Water         O=C1CC(C2=CC=C([N+]([O-])=O)C=C2)=NO1
# 9      Water                   O=C1C=C(C2=CC=C(OC)C=C2)NO1
# 12     Water      O=C2C3=C(C=CC=C3)/C(C=C2)=N/NC1=CC=CC=C1
# 13     Water   O=C2C3=C(C=CC=C3)/C(C=C2)=N/NC1=CC=C(C)C=C1
# 14     Water  O=C2C3=C(C=CC=C3)/C(C=C2)=N/NC1=CC=C(Cl)C=C1
# 15     Water  O=C2C3=C(C=CC=C3)/C(C=C2)=N/NC1=CC=C(OC)C=C1
# 16     Water                           ON1N=C2C=CC=CC2=C1C
# 17  Water-d2              OB(C1=C(C(F)=CC([H])=C1)C=O)O[H]
# 18  Water-d2                                    O=C1NCC=C1
# 19     Water            O=[S](CC1=CC=NC=C1)(C2=CC=CC=C2)=O
# 20     Water                O=C1C3=C(CC2=C1C=CC=C2)C=CC=C3
#
#    Quantitative_ratio_1                                    SMILES_2  \
# 0                  0.55                            OC1=CC(Cl)=NC=C1
# 1                   0.7                                O=C1N=CNC=C1
# 5                   0.2                 O=C1C(Br)=C(C2=CC=CC=C2)NO1
# 6                   0.3                               O=C1CC(C)=NO1
# 7                   0.7                        O=C1C=C(C(C)(C)C)NO1
# 8                   0.8       O=C1C=C(C2=CC=C([N+]([O-])=O)C=C2)NO1
# 9                   0.2                 O=C1CC(C2=CC=C(OC)C=C2)=NO1
# 12             0.701493      OC4=CC=C(/N=N/C6=CC=CC=C6)C5=C4C=CC=C5
# 13             0.579832   OC4=CC=C(/N=N/C6=CC=C(C)C=C6)C5=C4C=CC=C5
# 14             0.642857  OC4=CC=C(/N=N/C6=CC=C(Cl)C=C6)C5=C4C=CC=C5
# 15             0.450549  OC4=CC=C(/N=N/C6=CC=C(OC)C=C6)C5=C4C=CC=C5
# 16                 0.35            [O-][N+]3=C(C)C4=C(N3[H])C=CC=C4
# 17             0.854701             OB(C2=C3C(F)=CC([H])=C2)OC3O[H]
# 18               66.667                                  O=C1NC=CC1
# 19                99.99          O=[S](C=C1C=CNC=C1)(C2=CC=CC=C2)=O
# 20                99.32                OC2=C1C=CC=CC1=CC3=C2C=CC=C3
#
#    Quantitative_ratio_2
# 0                  0.45
# 1                   0.3
# 5                   0.8
# 6                   0.7
# 7                   0.3
# 8                   0.2
# 9                   0.8
# 12             0.298507
# 13             0.420168
# 14             0.357143
# 15             0.549451
# 16                 0.65
# 17             0.145299
# 18               33.333
# 19                    0
# 20                 0.68

# %%
TDB.loc[19,'Quantitative_ratio_2']=100-TDB.loc[19,'Quantitative_ratio_1']
TDB=TDB.reset_index(drop=True)
TDB
# Out:
#      Solvent                                      SMILES_1  \
# 0      Water                              O=C1C=C(Cl)NC=C1
# 1      Water                                  O=C1NC=NC=C1
# 2      Water                   O=C1C(Br)C(C2=CC=CC=C2)=NO1
# 3      Water                                 O=C1C=C(C)NO1
# 4      Water                          O=C1CC(C(C)(C)C)=NO1
# 5      Water         O=C1CC(C2=CC=C([N+]([O-])=O)C=C2)=NO1
# 6      Water                   O=C1C=C(C2=CC=C(OC)C=C2)NO1
# 7      Water      O=C2C3=C(C=CC=C3)/C(C=C2)=N/NC1=CC=CC=C1
# 8      Water   O=C2C3=C(C=CC=C3)/C(C=C2)=N/NC1=CC=C(C)C=C1
# 9      Water  O=C2C3=C(C=CC=C3)/C(C=C2)=N/NC1=CC=C(Cl)C=C1
# 10     Water  O=C2C3=C(C=CC=C3)/C(C=C2)=N/NC1=CC=C(OC)C=C1
# 11     Water                           ON1N=C2C=CC=CC2=C1C
# 12  Water-d2              OB(C1=C(C(F)=CC([H])=C1)C=O)O[H]
# 13  Water-d2                                    O=C1NCC=C1
# 14     Water            O=[S](CC1=CC=NC=C1)(C2=CC=CC=C2)=O
# 15     Water                O=C1C3=C(CC2=C1C=CC=C2)C=CC=C3
#
#    Quantitative_ratio_1                                    SMILES_2  \
# 0                  0.55                            OC1=CC(Cl)=NC=C1
# 1                   0.7                                O=C1N=CNC=C1
# 2                   0.2                 O=C1C(Br)=C(C2=CC=CC=C2)NO1
# 3                   0.3                               O=C1CC(C)=NO1
# 4                   0.7                        O=C1C=C(C(C)(C)C)NO1
# 5                   0.8       O=C1C=C(C2=CC=C([N+]([O-])=O)C=C2)NO1
# 6                   0.2                 O=C1CC(C2=CC=C(OC)C=C2)=NO1
# 7              0.701493      OC4=CC=C(/N=N/C6=CC=CC=C6)C5=C4C=CC=C5
# 8              0.579832   OC4=CC=C(/N=N/C6=CC=C(C)C=C6)C5=C4C=CC=C5
# 9              0.642857  OC4=CC=C(/N=N/C6=CC=C(Cl)C=C6)C5=C4C=CC=C5
# 10             0.450549  OC4=CC=C(/N=N/C6=CC=C(OC)C=C6)C5=C4C=CC=C5
# 11                 0.35            [O-][N+]3=C(C)C4=C(N3[H])C=CC=C4
# 12             0.854701             OB(C2=C3C(F)=CC([H])=C2)OC3O[H]
# 13               66.667                                  O=C1NC=CC1
# 14                99.99          O=[S](C=C1C=CNC=C1)(C2=CC=CC=C2)=O
# 15                99.32                OC2=C1C=CC=CC1=CC3=C2C=CC=C3
#
#    Quantitative_ratio_2
# 0                  0.45
# 1                   0.3
# 2                   0.8
# 3                   0.7
# 4                   0.3
# 5                   0.2
# 6                   0.8
# 7              0.298507
# 8              0.420168
# 9              0.357143
# 10             0.549451
# 11                 0.65
# 12             0.145299
# 13               33.333
# 14                 0.01
# 15                 0.68

# %%
TDB['KT']=TDB['Quantitative_ratio_2']/TDB['Quantitative_ratio_1']
TDB=TDB[['SMILES_1', 'SMILES_2', 'KT']]
TDB
# Out:
#                                         SMILES_1  \
# 0                               O=C1C=C(Cl)NC=C1
# 1                                   O=C1NC=NC=C1
# 2                    O=C1C(Br)C(C2=CC=CC=C2)=NO1
# 3                                  O=C1C=C(C)NO1
# 4                           O=C1CC(C(C)(C)C)=NO1
# 5          O=C1CC(C2=CC=C([N+]([O-])=O)C=C2)=NO1
# 6                    O=C1C=C(C2=CC=C(OC)C=C2)NO1
# 7       O=C2C3=C(C=CC=C3)/C(C=C2)=N/NC1=CC=CC=C1
# 8    O=C2C3=C(C=CC=C3)/C(C=C2)=N/NC1=CC=C(C)C=C1
# 9   O=C2C3=C(C=CC=C3)/C(C=C2)=N/NC1=CC=C(Cl)C=C1
# 10  O=C2C3=C(C=CC=C3)/C(C=C2)=N/NC1=CC=C(OC)C=C1
# 11                           ON1N=C2C=CC=CC2=C1C
# 12              OB(C1=C(C(F)=CC([H])=C1)C=O)O[H]
# 13                                    O=C1NCC=C1
# 14            O=[S](CC1=CC=NC=C1)(C2=CC=CC=C2)=O
# 15                O=C1C3=C(CC2=C1C=CC=C2)C=CC=C3
#
#                                       SMILES_2        KT
# 0                             OC1=CC(Cl)=NC=C1  0.818182
# 1                                 O=C1N=CNC=C1  0.428571
# 2                  O=C1C(Br)=C(C2=CC=CC=C2)NO1       4.0
# 3                                O=C1CC(C)=NO1  2.333333
# 4                         O=C1C=C(C(C)(C)C)NO1  0.428571
# 5        O=C1C=C(C2=CC=C([N+]([O-])=O)C=C2)NO1      0.25
# 6                  O=C1CC(C2=CC=C(OC)C=C2)=NO1       4.0
# 7       OC4=CC=C(/N=N/C6=CC=CC=C6)C5=C4C=CC=C5  0.425532
# 8    OC4=CC=C(/N=N/C6=CC=C(C)C=C6)C5=C4C=CC=C5  0.724638
# 9   OC4=CC=C(/N=N/C6=CC=C(Cl)C=C6)C5=C4C=CC=C5  0.555556
# 10  OC4=CC=C(/N=N/C6=CC=C(OC)C=C6)C5=C4C=CC=C5  1.219512
# 11            [O-][N+]3=C(C)C4=C(N3[H])C=CC=C4  1.857143
# 12             OB(C2=C3C(F)=CC([H])=C2)OC3O[H]      0.17
# 13                                  O=C1NC=CC1  0.499993
# 14          O=[S](C=C1C=CNC=C1)(C2=CC=CC=C2)=O    0.0001
# 15                OC2=C1C=CC=CC1=CC3=C2C=CC=C3  0.006847

# %%
TB=pd.read_excel('Tautobase.xlsx', usecols=['SMILES_1', 'SMILES_2', 'logK', '% (Tautomer1)',  'Solvent','Meas'])
TB
# Out:
#                                          SMILES_1  \
# 0                              CC(C)C1=C(C)CCCCC1
# 1                               CC(C)C1=C(C)CCCC1
# 2                                CC(C)C1=C(C)CCC1
# 3                          CC(C)/C1=C(\C)/CCCCCC1
# 4     FC(c1c2nc(C(F)(F)F)[nH]n2c(C(F)(F)F)n1)(F)F
# ...                                           ...
# 1675              C(CC1)CCC1Nc1ccnc2c3ncccc3ccc12
# 1676                    C(C1c2ccccc2)N=Nc2c1cccc2
# 1677                    C(C1c2ccccc2)=NNc2c1cccc2
# 1678          C(C1)CN=C2N1C(c1ccccc1)c(cccc1)c1N2
# 1679                                 Brc1cnn[nH]1
#
#                                          SMILES_2  logK % (Tautomer1)  \
# 0                              CC(CCCCC1)C1=C(C)C -0.21           NaN
# 1                               CC(CCCC1)C1=C(C)C -0.86           NaN
# 2                                CC(CCC1)C1=C(C)C  0.18           NaN
# 3                             CC(CCCCCC1)C1=C(C)C -0.75           NaN
# 4     FC(c(nc1C(F)(F)F)c2n1nc(C(F)(F)F)[nH]2)(F)F   NaN           100
# ...                                           ...   ...           ...
# 1675        C(CC1)CCC1/N=C1\c2ccc(cccn3)c3c2NC=C1  -4.8           NaN
# 1676                    C(C1c2ccccc2)=NNc2c1cccc2   NaN             0
# 1677                    c(cc1)ccc1C1=CNNc2c1cccc2   NaN           100
# 1678            C(CN1)CN(C2c3ccccc3)C1=Nc1c2cccc1  1.44           NaN
# 1679                                 Brc1c[nH]nn1   1.2           NaN
#
#           Solvent Meas
# 0     Acetic acid  NaN
# 1     Acetic acid  NaN
# 2     Acetic acid  NaN
# 3     Acetic acid  NaN
# 4         Acetone  NaN
# ...           ...  ...
# 1675          NaN  NaN
# 1676          NaN  NaN
# 1677          NaN  NaN
# 1678          NaN  NaN
# 1679          NaN  NaN
#
# [1680 rows x 6 columns]

# %%
TB=TB.query("Solvent=='Water'")
TB=TB.query("Meas=='E'")
TB=TB.reset_index(drop=True)
TB
# Out:
#                             SMILES_1                           SMILES_2 logK  \
# 0                 c(cc1)cc2c1nn[nH]2                   c1cc2n[nH]nc2cc1  NaN
# 1            [O-][N+](c(cncc1)c1O)=O           [O-][N+](C1=CNC=CC1=O)=O  3.9
# 2    [O-][N+](c(cc1)cc(C2)c1NC2=O)=O  [O-][N+](c(cc1)cc2c1[nH]c(O)c2)=O -6.5
# 3        [O-][N+](Cc1nncc2ccccc12)=O    [O-][N+](/C=C1/NN=Cc2c1cccc2)=O  NaN
# 4              [O-][N+](Cc1ncncc1)=O         [O-][N+](/C=C1\NC=NC=C1)=O  NaN
# ..                               ...                                ...  ...
# 292               C/N=C(/c1ccccc1)\S                    CNC(c1ccccc1)=S  8.8
# 293               C/N=C(/c1ccccc1)\O                    CNC(c1ccccc1)=O  8.6
# 294            C/C(/c(cccc1)c1O)=N\C          C/C(/NC)=C(\C=CC=C1)/C1=O  0.6
# 295                      C/C(/O)=N/C                           CC(NC)=O  9.1
# 296              C/C(/Cc1ncccc1)=N\C                C/C(/NC)=C/c1ncccc1  NaN
#
#     % (Tautomer1) Solvent Meas
# 0              96   Water    E
# 1             NaN   Water    E
# 2             NaN   Water    E
# 3             NaN   Water    E
# 4             NaN   Water    E
# ..            ...     ...  ...
# 292           NaN   Water    E
# 293           NaN   Water    E
# 294           NaN   Water    E
# 295           NaN   Water    E
# 296           NaN   Water    E
#
# [297 rows x 6 columns]

# %%
for i in range(len(TB)):
    if pd.isnull(TB.loc[i, '% (Tautomer1)']) and pd.isnull(TB.loc[i, 'logK']):
        TB=TB.drop(i)
        
TB=TB.reset_index(drop=True)
TB
# Out:
#                             SMILES_1                           SMILES_2 logK  \
# 0                 c(cc1)cc2c1nn[nH]2                   c1cc2n[nH]nc2cc1  NaN
# 1            [O-][N+](c(cncc1)c1O)=O           [O-][N+](C1=CNC=CC1=O)=O  3.9
# 2    [O-][N+](c(cc1)cc(C2)c1NC2=O)=O  [O-][N+](c(cc1)cc2c1[nH]c(O)c2)=O -6.5
# 3         [O-][N+](CC(c1ccccc1)=O)=O      [O-][N+](/C=C(/c1ccccc1)\O)=O -2.3
# 4      [O-][N+](C(Cc1c2cccc1)C2=O)=O      [O-][N+](C(Cc1c2cccc1)=C2O)=O -1.7
# ..                               ...                                ...  ...
# 179          C/N=C/C1Oc(cccc2)c2C1=O            CN/C=C1/Oc(cccc2)c2C1=O  NaN
# 180               C/N=C(/c1ccccc1)\S                    CNC(c1ccccc1)=S  8.8
# 181               C/N=C(/c1ccccc1)\O                    CNC(c1ccccc1)=O  8.6
# 182            C/C(/c(cccc1)c1O)=N\C          C/C(/NC)=C(\C=CC=C1)/C1=O  0.6
# 183                      C/C(/O)=N/C                           CC(NC)=O  9.1
#
#     % (Tautomer1) Solvent Meas
# 0              96   Water    E
# 1             NaN   Water    E
# 2             NaN   Water    E
# 3             NaN   Water    E
# 4             NaN   Water    E
# ..            ...     ...  ...
# 179             0   Water    E
# 180           NaN   Water    E
# 181           NaN   Water    E
# 182           NaN   Water    E
# 183           NaN   Water    E
#
# [184 rows x 6 columns]

# %%
for i in range(len(TB)):
    if TB.loc[i, '% (Tautomer1)']==0 or TB.loc[i, '% (Tautomer1)']==100:
        TB=TB.drop(i)

TB=TB.reset_index(drop=True)
TB
# Out:
#                             SMILES_1                           SMILES_2 logK  \
# 0                 c(cc1)cc2c1nn[nH]2                   c1cc2n[nH]nc2cc1  NaN
# 1            [O-][N+](c(cncc1)c1O)=O           [O-][N+](C1=CNC=CC1=O)=O  3.9
# 2    [O-][N+](c(cc1)cc(C2)c1NC2=O)=O  [O-][N+](c(cc1)cc2c1[nH]c(O)c2)=O -6.5
# 3         [O-][N+](CC(c1ccccc1)=O)=O      [O-][N+](/C=C(/c1ccccc1)\O)=O -2.3
# 4      [O-][N+](C(Cc1c2cccc1)C2=O)=O      [O-][N+](C(Cc1c2cccc1)=C2O)=O -1.7
# ..                               ...                                ...  ...
# 174                C/N=N/c(cccc1)c1O              CN/N=C(/C=CC=C1)\C1=O  0.2
# 175               C/N=C(/c1ccccc1)\S                    CNC(c1ccccc1)=S  8.8
# 176               C/N=C(/c1ccccc1)\O                    CNC(c1ccccc1)=O  8.6
# 177            C/C(/c(cccc1)c1O)=N\C          C/C(/NC)=C(\C=CC=C1)/C1=O  0.6
# 178                      C/C(/O)=N/C                           CC(NC)=O  9.1
#
#     % (Tautomer1) Solvent Meas
# 0              96   Water    E
# 1             NaN   Water    E
# 2             NaN   Water    E
# 3             NaN   Water    E
# 4             NaN   Water    E
# ..            ...     ...  ...
# 174           NaN   Water    E
# 175           NaN   Water    E
# 176           NaN   Water    E
# 177           NaN   Water    E
# 178           NaN   Water    E
#
# [179 rows x 6 columns]

# %%
for i in range(len(TB)):
    if type(TB.loc[i,'logK'])==str:
        TB=TB.drop(i)

TB=TB.reset_index(drop=True)
TB
# Out:
#                             SMILES_1                           SMILES_2 logK  \
# 0                 c(cc1)cc2c1nn[nH]2                   c1cc2n[nH]nc2cc1  NaN
# 1            [O-][N+](c(cncc1)c1O)=O           [O-][N+](C1=CNC=CC1=O)=O  3.9
# 2    [O-][N+](c(cc1)cc(C2)c1NC2=O)=O  [O-][N+](c(cc1)cc2c1[nH]c(O)c2)=O -6.5
# 3         [O-][N+](CC(c1ccccc1)=O)=O      [O-][N+](/C=C(/c1ccccc1)\O)=O -2.3
# 4      [O-][N+](C(Cc1c2cccc1)C2=O)=O      [O-][N+](C(Cc1c2cccc1)=C2O)=O -1.7
# ..                               ...                                ...  ...
# 162                C/N=N/c(cccc1)c1O              CN/N=C(/C=CC=C1)\C1=O  0.2
# 163               C/N=C(/c1ccccc1)\S                    CNC(c1ccccc1)=S  8.8
# 164               C/N=C(/c1ccccc1)\O                    CNC(c1ccccc1)=O  8.6
# 165            C/C(/c(cccc1)c1O)=N\C          C/C(/NC)=C(\C=CC=C1)/C1=O  0.6
# 166                      C/C(/O)=N/C                           CC(NC)=O  9.1
#
#     % (Tautomer1) Solvent Meas
# 0              96   Water    E
# 1             NaN   Water    E
# 2             NaN   Water    E
# 3             NaN   Water    E
# 4             NaN   Water    E
# ..            ...     ...  ...
# 162           NaN   Water    E
# 163           NaN   Water    E
# 164           NaN   Water    E
# 165           NaN   Water    E
# 166           NaN   Water    E
#
# [167 rows x 6 columns]

# %%
for i in range(len(TB)):
    if pd.isnull(TB.loc[i, '% (Tautomer1)']):
        TB.loc[i, 'KT']=10**TB.loc[i, 'logK']
    if pd.isnull(TB.loc[i, 'logK']):
        TB.loc[i, 'KT']=(100-TB.loc[i, '% (Tautomer1)'])/(TB.loc[i, '% (Tautomer1)'])

TB
# Out:
#                             SMILES_1                           SMILES_2 logK  \
# 0                 c(cc1)cc2c1nn[nH]2                   c1cc2n[nH]nc2cc1  NaN
# 1            [O-][N+](c(cncc1)c1O)=O           [O-][N+](C1=CNC=CC1=O)=O  3.9
# 2    [O-][N+](c(cc1)cc(C2)c1NC2=O)=O  [O-][N+](c(cc1)cc2c1[nH]c(O)c2)=O -6.5
# 3         [O-][N+](CC(c1ccccc1)=O)=O      [O-][N+](/C=C(/c1ccccc1)\O)=O -2.3
# 4      [O-][N+](C(Cc1c2cccc1)C2=O)=O      [O-][N+](C(Cc1c2cccc1)=C2O)=O -1.7
# ..                               ...                                ...  ...
# 162                C/N=N/c(cccc1)c1O              CN/N=C(/C=CC=C1)\C1=O  0.2
# 163               C/N=C(/c1ccccc1)\S                    CNC(c1ccccc1)=S  8.8
# 164               C/N=C(/c1ccccc1)\O                    CNC(c1ccccc1)=O  8.6
# 165            C/C(/c(cccc1)c1O)=N\C          C/C(/NC)=C(\C=CC=C1)/C1=O  0.6
# 166                      C/C(/O)=N/C                           CC(NC)=O  9.1
#
#     % (Tautomer1) Solvent Meas            KT
# 0              96   Water    E  4.166667e-02
# 1             NaN   Water    E  7.943282e+03
# 2             NaN   Water    E  3.162278e-07
# 3             NaN   Water    E  5.011872e-03
# 4             NaN   Water    E  1.995262e-02
# ..            ...     ...  ...           ...
# 162           NaN   Water    E  1.584893e+00
# 163           NaN   Water    E  6.309573e+08
# 164           NaN   Water    E  3.981072e+08
# 165           NaN   Water    E  3.981072e+00
# 166           NaN   Water    E  1.258925e+09
#
# [167 rows x 7 columns]

# %%
TB.sample(10)
# Out:
#                              SMILES_1                       SMILES_2 logK  \
# 57                         O=C1NN=CN1                    Oc1n[nH]cn1 -3.9
# 85           O=C(C(Cl)(Cl)Cl)Nc1nncs1   O=C(C(Cl)(Cl)Cl)/N=C1\SC=NN1  1.6
# 36                         OC1=NNCCC1                     O=C1NNCCC1  5.1
# 47                    OC(N1)=NC=CC1=O                O=C(C=CN1)NC1=O  5.8
# 33                  Oc(c(Cl)cnc1)c1Cl             O=C1C(Cl)=CNC=C1Cl  2.9
# 7                            Oc1nocc1                     O=C1NOC=C1   -2
# 9                           Oc1nnccn1                   O=C1N=CC=NN1  5.1
# 160  CC(C)(C/C(/C1)=N\Nc2ccccc2)CC1=O  CC(C)(C1)CC(NNc2ccccc2)=CC1=O  2.5
# 94                       Nc1cccc(O)n1                NC(N1)=CC=CC1=O  3.3
# 91                        Nc1nc(O)co1                  N=C(N1)OCC1=O    4
#
#     % (Tautomer1) Solvent Meas             KT
# 57            NaN   Water    E       0.000126
# 85            NaN   Water    E      39.810717
# 36            NaN   Water    E  125892.541179
# 47            NaN   Water    E  630957.344480
# 33            NaN   Water    E     794.328235
# 7             NaN   Water    E       0.010000
# 9             NaN   Water    E  125892.541179
# 160           NaN   Water    E     316.227766
# 94            NaN   Water    E    1995.262315
# 91            NaN   Water    E   10000.000000

# %%
TB=TB[['SMILES_1', 'SMILES_2', 'KT']]
TB
# Out:
#                             SMILES_1                           SMILES_2  \
# 0                 c(cc1)cc2c1nn[nH]2                   c1cc2n[nH]nc2cc1
# 1            [O-][N+](c(cncc1)c1O)=O           [O-][N+](C1=CNC=CC1=O)=O
# 2    [O-][N+](c(cc1)cc(C2)c1NC2=O)=O  [O-][N+](c(cc1)cc2c1[nH]c(O)c2)=O
# 3         [O-][N+](CC(c1ccccc1)=O)=O      [O-][N+](/C=C(/c1ccccc1)\O)=O
# 4      [O-][N+](C(Cc1c2cccc1)C2=O)=O      [O-][N+](C(Cc1c2cccc1)=C2O)=O
# ..                               ...                                ...
# 162                C/N=N/c(cccc1)c1O              CN/N=C(/C=CC=C1)\C1=O
# 163               C/N=C(/c1ccccc1)\S                    CNC(c1ccccc1)=S
# 164               C/N=C(/c1ccccc1)\O                    CNC(c1ccccc1)=O
# 165            C/C(/c(cccc1)c1O)=N\C          C/C(/NC)=C(\C=CC=C1)/C1=O
# 166                      C/C(/O)=N/C                           CC(NC)=O
#
#                KT
# 0    4.166667e-02
# 1    7.943282e+03
# 2    3.162278e-07
# 3    5.011872e-03
# 4    1.995262e-02
# ..            ...
# 162  1.584893e+00
# 163  6.309573e+08
# 164  3.981072e+08
# 165  3.981072e+00
# 166  1.258925e+09
#
# [167 rows x 3 columns]

# %%
taut=pd.concat([TDB, TB], ignore_index=True)
taut.index.name = 'TautID'
taut
# Out:
#                            SMILES_1                     SMILES_2  \
# TautID
# 0                  O=C1C=C(Cl)NC=C1             OC1=CC(Cl)=NC=C1
# 1                      O=C1NC=NC=C1                 O=C1N=CNC=C1
# 2       O=C1C(Br)C(C2=CC=CC=C2)=NO1  O=C1C(Br)=C(C2=CC=CC=C2)NO1
# 3                     O=C1C=C(C)NO1                O=C1CC(C)=NO1
# 4              O=C1CC(C(C)(C)C)=NO1         O=C1C=C(C(C)(C)C)NO1
# ...                             ...                          ...
# 178               C/N=N/c(cccc1)c1O        CN/N=C(/C=CC=C1)\C1=O
# 179              C/N=C(/c1ccccc1)\S              CNC(c1ccccc1)=S
# 180              C/N=C(/c1ccccc1)\O              CNC(c1ccccc1)=O
# 181           C/C(/c(cccc1)c1O)=N\C    C/C(/NC)=C(\C=CC=C1)/C1=O
# 182                     C/C(/O)=N/C                     CC(NC)=O
#
#                        KT
# TautID
# 0                0.818182
# 1                0.428571
# 2                     4.0
# 3                2.333333
# 4                0.428571
# ...                   ...
# 178              1.584893
# 179      630957344.480194
# 180      398107170.553497
# 181              3.981072
# 182     1258925411.794166
#
# [183 rows x 3 columns]

# %%
taut['KT'] = taut['KT'].astype("float64")
taut['logKT']=np.log10(taut['KT'])
taut
# Out:
#                            SMILES_1                     SMILES_2  \
# TautID
# 0                  O=C1C=C(Cl)NC=C1             OC1=CC(Cl)=NC=C1
# 1                      O=C1NC=NC=C1                 O=C1N=CNC=C1
# 2       O=C1C(Br)C(C2=CC=CC=C2)=NO1  O=C1C(Br)=C(C2=CC=CC=C2)NO1
# 3                     O=C1C=C(C)NO1                O=C1CC(C)=NO1
# 4              O=C1CC(C(C)(C)C)=NO1         O=C1C=C(C(C)(C)C)NO1
# ...                             ...                          ...
# 178               C/N=N/c(cccc1)c1O        CN/N=C(/C=CC=C1)\C1=O
# 179              C/N=C(/c1ccccc1)\S              CNC(c1ccccc1)=S
# 180              C/N=C(/c1ccccc1)\O              CNC(c1ccccc1)=O
# 181           C/C(/c(cccc1)c1O)=N\C    C/C(/NC)=C(\C=CC=C1)/C1=O
# 182                     C/C(/O)=N/C                     CC(NC)=O
#
#                   KT     logKT
# TautID
# 0       8.181818e-01 -0.087150
# 1       4.285714e-01 -0.367977
# 2       4.000000e+00  0.602060
# 3       2.333333e+00  0.367977
# 4       4.285714e-01 -0.367977
# ...              ...       ...
# 178     1.584893e+00  0.200000
# 179     6.309573e+08  8.800000
# 180     3.981072e+08  8.600000
# 181     3.981072e+00  0.600000
# 182     1.258925e+09  9.100000
#
# [183 rows x 4 columns]

# %%
taut.sample(10)
# Out:
#                                 SMILES_1                         SMILES_2  \
# TautID
# 87                     O=C1N2N=CNC2=NCC1                  O=C1n2ncnc2NCC1
# 119                      NC(NN=C1)=NC1=O                  N=C(N1)NN=CC1=O
# 65                       OC(N1)=CC=CC1=O                     Oc1cccc(O)n1
# 152                 CCOC(CC(C(C)=O)=O)=O          CCOC(/C=C(/C(C)=O)\O)=O
# 84                    O=C1N2N=NNC2=NC=C1                 O=C1n2nnnc2NC=C1
# 24                             Oc1nncnc1                     O=C1NN=CN=C1
# 142                      CSc([nH]1)ncc1O                   CSC(NC1)=NC1=O
# 23                              Oc1nocc1                       O=C1NOC=C1
# 138                      Cc1c(C)n(C)nc1O                CC1=C(C)N(C)NC1=O
# 88      O=C1N(c(cccc2)c2N2)C2=Nc2c1cccc2  O=C(c(cccc1)c1N1)n2c1nc1c2cccc1
#
#                   KT  logKT
# TautID
# 87      1.995262e+06    6.3
# 119     3.162278e-05   -4.5
# 65      5.011872e-02   -1.3
# 152     1.000000e+02    2.0
# 84      6.309573e+00    0.8
# 24      3.162278e+03    3.5
# 142     1.000000e+01    1.0
# 23      1.000000e-02   -2.0
# 138     1.995262e+01    1.3
# 88      3.981072e-03   -2.4

# %%
ma=0
mi=0
c=0
for i in range(len(taut)):
    if taut.loc[i, 'logKT']>0:
        ma=ma+1
    if taut.loc[i, 'logKT']<0:
        mi=mi+1
    if taut.loc[i, 'logKT']==0:
        c=c+1

# %%
print('Número de equilibrios donde predomina el producto:', ma)
print('Número de equilibrios donde predomina el reactivo:', mi)
print('Número de equilibrios donde producto y reactivo están en misma proporción:', c)
# Out:
# Número de equilibrios donde predomina el producto: 103
# Número de equilibrios donde predomina el reactivo: 76
# Número de equilibrios donde producto y reactivo están en misma proporción: 4

# %%
for i in range(len(taut)):
    if taut.loc[i, 'logKT']>0 or taut.loc[i, 'logKT']==0:
        taut.loc[i,'T1']=taut.loc[i,'SMILES_1']
        taut.loc[i,'T2']=taut.loc[i,'SMILES_2']
        taut.loc[i,'logK']=taut.loc[i,'logKT']
    if taut.loc[i, 'logKT']<0:
        taut.loc[i,'T1']=taut.loc[i,'SMILES_2']
        taut.loc[i,'T2']=taut.loc[i,'SMILES_1']
        taut.loc[i,'KT'] = 1/taut.loc[i,'KT']
        taut.loc[i,'logK'] = np.log10(taut.loc[i,'KT'])


taut
# Out:
#                            SMILES_1                     SMILES_2  \
# TautID
# 0                  O=C1C=C(Cl)NC=C1             OC1=CC(Cl)=NC=C1
# 1                      O=C1NC=NC=C1                 O=C1N=CNC=C1
# 2       O=C1C(Br)C(C2=CC=CC=C2)=NO1  O=C1C(Br)=C(C2=CC=CC=C2)NO1
# 3                     O=C1C=C(C)NO1                O=C1CC(C)=NO1
# 4              O=C1CC(C(C)(C)C)=NO1         O=C1C=C(C(C)(C)C)NO1
# ...                             ...                          ...
# 178               C/N=N/c(cccc1)c1O        CN/N=C(/C=CC=C1)\C1=O
# 179              C/N=C(/c1ccccc1)\S              CNC(c1ccccc1)=S
# 180              C/N=C(/c1ccccc1)\O              CNC(c1ccccc1)=O
# 181           C/C(/c(cccc1)c1O)=N\C    C/C(/NC)=C(\C=CC=C1)/C1=O
# 182                     C/C(/O)=N/C                     CC(NC)=O
#
#                   KT     logKT                           T1  \
# TautID
# 0       1.222222e+00 -0.087150             OC1=CC(Cl)=NC=C1
# 1       2.333333e+00 -0.367977                 O=C1N=CNC=C1
# 2       4.000000e+00  0.602060  O=C1C(Br)C(C2=CC=CC=C2)=NO1
# 3       2.333333e+00  0.367977                O=C1C=C(C)NO1
# 4       2.333333e+00 -0.367977         O=C1C=C(C(C)(C)C)NO1
# ...              ...       ...                          ...
# 178     1.584893e+00  0.200000            C/N=N/c(cccc1)c1O
# 179     6.309573e+08  8.800000           C/N=C(/c1ccccc1)\S
# 180     3.981072e+08  8.600000           C/N=C(/c1ccccc1)\O
# 181     3.981072e+00  0.600000        C/C(/c(cccc1)c1O)=N\C
# 182     1.258925e+09  9.100000                  C/C(/O)=N/C
#
#                                  T2      logK
# TautID
# 0                  O=C1C=C(Cl)NC=C1  0.087150
# 1                      O=C1NC=NC=C1  0.367977
# 2       O=C1C(Br)=C(C2=CC=CC=C2)NO1  0.602060
# 3                     O=C1CC(C)=NO1  0.367977
# 4              O=C1CC(C(C)(C)C)=NO1  0.367977
# ...                             ...       ...
# 178           CN/N=C(/C=CC=C1)\C1=O  0.200000
# 179                 CNC(c1ccccc1)=S  8.800000
# 180                 CNC(c1ccccc1)=O  8.600000
# 181       C/C(/NC)=C(\C=CC=C1)/C1=O  0.600000
# 182                        CC(NC)=O  9.100000
#
# [183 rows x 7 columns]

# %%
taut=taut[['SMILES_1','SMILES_2','T1','T2', 'KT', 'logKT', 'logK']]
taut.sample(10)
# Out:
#                           SMILES_1                         SMILES_2  \
# TautID
# 91            O=C1N(C=CN2)C2=NC=C1               O=C(C=CN1)n2c1ncc2
# 140                Cc1c(C)[nH]nc1O                   CC1=C(C)NNC1=O
# 32                 Oc1ncnc2ccccc12                O=C1N=CNc2c1cccc2
# 131      Cn1nnnc1NC(C(Cl)(Cl)Cl)=O    CN1N=NN/C1=N/C(C(Cl)(Cl)Cl)=O
# 83       O=C1N=C(NC=C2)N2c2c1cccc2           O=C1Nc2nccn2-c2c1cccc2
# 69      O=S(Cc1ncccc1)(C(F)(F)F)=O  O=S(C(F)(F)F)(/C=C1/NC=CC=C1)=O
# 61          OC(c(cccc1)c1N1)=NC1=O           O=C(c(cccc1)c1N1)NC1=O
# 118           NC(Nc1c2cccc1)=NC2=O             N=C(Nc1c2cccc1)NC2=O
# 49               Oc(c(Cl)cnc1)c1Cl               O=C1C(Cl)=CNC=C1Cl
# 51                       OC1=NOCC1                        O=C1NOCC1
#
#                                      T1                             T2  \
# TautID
# 91                   O=C(C=CN1)n2c1ncc2           O=C1N(C=CN2)C2=NC=C1
# 140                     Cc1c(C)[nH]nc1O                 CC1=C(C)NNC1=O
# 32                      Oc1ncnc2ccccc12              O=C1N=CNc2c1cccc2
# 131           Cn1nnnc1NC(C(Cl)(Cl)Cl)=O  CN1N=NN/C1=N/C(C(Cl)(Cl)Cl)=O
# 83               O=C1Nc2nccn2-c2c1cccc2      O=C1N=C(NC=C2)N2c2c1cccc2
# 69      O=S(C(F)(F)F)(/C=C1/NC=CC=C1)=O     O=S(Cc1ncccc1)(C(F)(F)F)=O
# 61               OC(c(cccc1)c1N1)=NC1=O         O=C(c(cccc1)c1N1)NC1=O
# 118                N=C(Nc1c2cccc1)NC2=O           NC(Nc1c2cccc1)=NC2=O
# 49                    Oc(c(Cl)cnc1)c1Cl             O=C1C(Cl)=CNC=C1Cl
# 51                            OC1=NOCC1                      O=C1NOCC1
#
#                   KT  logKT  logK
# TautID
# 91      3.162278e+03   -3.5   3.5
# 140     6.309573e+01    1.8   1.8
# 32      1.258925e+04    4.1   4.1
# 131     1.000000e+00    0.0   0.0
# 83      5.011872e+00   -0.7   0.7
# 69      3.981072e+02   -2.6   2.6
# 61      2.511886e+06    6.4   6.4
# 118     6.309573e+03   -3.8   3.8
# 49      7.943282e+02    2.9   2.9
# 51      1.258925e+02    2.1   2.1

# %%
taut=taut[['T1','T2', 'logK']]
tauts=taut
taut
# Out:
#                                  T1                           T2      logK
# TautID
# 0                  OC1=CC(Cl)=NC=C1             O=C1C=C(Cl)NC=C1  0.087150
# 1                      O=C1N=CNC=C1                 O=C1NC=NC=C1  0.367977
# 2       O=C1C(Br)C(C2=CC=CC=C2)=NO1  O=C1C(Br)=C(C2=CC=CC=C2)NO1  0.602060
# 3                     O=C1C=C(C)NO1                O=C1CC(C)=NO1  0.367977
# 4              O=C1C=C(C(C)(C)C)NO1         O=C1CC(C(C)(C)C)=NO1  0.367977
# ...                             ...                          ...       ...
# 178               C/N=N/c(cccc1)c1O        CN/N=C(/C=CC=C1)\C1=O  0.200000
# 179              C/N=C(/c1ccccc1)\S              CNC(c1ccccc1)=S  8.800000
# 180              C/N=C(/c1ccccc1)\O              CNC(c1ccccc1)=O  8.600000
# 181           C/C(/c(cccc1)c1O)=N\C    C/C(/NC)=C(\C=CC=C1)/C1=O  0.600000
# 182                     C/C(/O)=N/C                     CC(NC)=O  9.100000
#
# [183 rows x 3 columns]

# %%
for i in range(len(tauts)):
    tauts.loc[i,'T1']=standardize_smiles(tauts.loc[i,'T1'])
    tauts.loc[i,'T2']=standardize_smiles(tauts.loc[i,'T2'])

tauts
# Out:
#                             T1                         T2      logK
# TautID
# 0                Oc1ccnc(Cl)c1          O=c1cc[nH]c(Cl)c1  0.087150
# 1                O=c1cc[nH]cn1              O=c1ccnc[nH]1  0.367977
# 2       O=C1ON=C(c2ccccc2)C1Br  O=c1o[nH]c(-c2ccccc2)c1Br  0.602060
# 3              Cc1cc(=O)o[nH]1              CC1=NOC(=O)C1  0.367977
# 4       CC(C)(C)c1cc(=O)o[nH]1       CC(C)(C)C1=NOC(=O)C1  0.367977
# ...                        ...                        ...       ...
# 178            C/N=N/c1ccccc1O         CN/N=C1/C=CC=CC1=O  0.200000
# 179          C/N=C(\S)c1ccccc1            CNC(=S)c1ccccc1  8.800000
# 180          C/N=C(\O)c1ccccc1            CNC(=O)c1ccccc1  8.600000
# 181         C/N=C(\C)c1ccccc1O      CN/C(C)=C1/C=CC=CC1=O  0.600000
# 182                 C/N=C(/C)O                   CNC(C)=O  9.100000
#
# [183 rows x 3 columns]

# %%
T1=tauts[['T1']]
T1.to_csv('T1.csv')

# %%
T2=tauts[['T2']]
T2.to_csv('T2.csv')

# %%
logK=tauts[['logK']]
logK.to_csv('logK.csv')
